# %%
import numpy as np
import pandas as pd

# %%
white_wine = pd.read_csv("white.csv", sep =";")

# %%
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white_wine['Color'] = 'White'

# %%
red_wine = pd.read_csv("red.csv", sep =";")

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
red_wine['Color'] = 'Red'

# %%
white_wine.shape
# Out:
# (4898, 13)

# %%
merge_data = pd.concat([white_wine,red_wine], axis = 0)

# %%
merge_data.tail(3000)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3497            7.7             0.430         1.00           19.95      0.032
# 3498            6.4             0.300         0.36            2.00      0.052
# 3499            6.1             0.330         0.30            3.00      0.036
# 3500            6.0             0.280         0.27           15.50      0.036
# 3501            6.7             0.240         0.36            8.40      0.042
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08            2.00      0.090
# 1595            5.9             0.550         0.10            2.20      0.062
# 1596            6.3             0.510         0.13            2.30      0.076
# 1597            5.9             0.645         0.12            2.00      0.075
# 1598            6.0             0.310         0.47            3.60      0.067
#
# ...

# %%
bins = [0, 6, 10]
names = ['Bad', 'Good']

merge_data['quality'] = pd.cut(merge_data['quality'], bins, labels=names)

# %%
merge_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
cols_numeric = merge_data.select_dtypes(include=numerics).columns.tolist()

# %%
cols_numeric
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
merge_data[cols_numeric]=scaler.fit_transform(merge_data[cols_numeric])

# %%
merge_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.264463          0.126667     0.216867        0.308282   0.059801
# 1          0.206612          0.146667     0.204819        0.015337   0.066445
# 2          0.355372          0.133333     0.240964        0.096626   0.068106
# 3          0.280992          0.100000     0.192771        0.121166   0.081395
# 4          0.280992          0.100000     0.192771        0.121166   0.081395
# ...             ...               ...          ...             ...        ...
# 1594       0.198347          0.346667     0.048193        0.021472   0.134551
# 1595       0.173554          0.313333     0.060241        0.024540   0.088040
# 1596       0.206612          0.286667     0.078313        0.026074   0.111296
# 1597       0.173554          0.376667     0.072289        0.021472   0.109635
# 1598       0.181818          0.153333     0.283133        0.046012   0.096346
#
# ...

# %%
merge_data['Color'].unique()
# Out:
# array(['White', 'Red'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

quality_encoder = LabelEncoder()
merge_data["quality"] = quality_encoder.fit_transform(merge_data["quality"])

# %%
from sklearn.preprocessing import LabelEncoder

color_encoder = LabelEncoder()
merge_data["Color"] = color_encoder.fit_transform(merge_data["Color"])

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.matshow(merge_data.corr(method='spearman'))
plt.xticks(range(len(merge_data.columns)), merge_data.columns)
plt.yticks(range(len(merge_data.columns)), merge_data.columns)
plt.colorbar()
plt.show()

# %%
import seaborn as sns
corr=merge_data.corr(method='spearman')
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
x = merge_data.drop('quality', 1)
y = merge_data['quality']

# %%
plt.figure(figsize=(12,10))
cor = merge_data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
